# %% [markdown]
# <a href="https://colab.research.google.com/github/masalazarl/MetNumUN2022II/blob/main/LAB%204/group5SymPyLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SymPyLab
#
# SymPy’s documentation
# - https://docs.sympy.org/latest/index.html

# %% [markdown]
# ## SymPy’s polynomials
# - https://docs.sympy.org/latest/modules/polys/basics.html#polynomials
#
# $$ P_n(x) =  a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0$$
#
# $$P_n(x) = 0 $$
#
# $$a_n x^n + a_{n-1} x^{n-1} + a_{n-2} x^{n-2} +\cdots +  a_1 x  + a_0 = 0$$
#
# $$(x-r_1) Q_{n-1}(x) = P_n(x)$$
# $$(x-r_1) (x - r_2) Q_{n-2}(x) = P_n(x)$$
# $$ \vdots $$
#
# (x+2)(x+5)(x-8)(x-1) = x^4 - 2 x^3 - 45 x^2 - 34 x + 80
#
# x^4 - 2 x^3 - 45 x^2 - 34 x + 80 = x^3 - x^2 - 46 x - 80

# %% [markdown]
# ![wolfram 2.png](data:image/png;base64,...)

# %% [markdown]
# ![Wolfram(2).png](data:image/png;base64,...)

# %%
from sympy import Symbol
from sympy import div

x = Symbol('x')

p = x**4 - 2*x**3 - 45*x**2 - 34*x + 80 

p, r = div(p,  x+2)

print(p)
print(r)

p, r = div(p,  x+5)

print(p)
print(r)

p, r = div(p,  x-8)

print(p)
print(r)

p, r = div(p,  x-1)

print(p)
print(r)
# Out:
# x**3 - 4*x**2 - 37*x + 40
# 0
# x**2 - 9*x + 8
# 0
# x - 1
# 0
# 1
# 0

# %%
p = x**4 - 2*x**3 - 45*x**2 - 34*x + 80 

p, r = div(p,  x-9)

print(p)
print(r)
# Out:
# x**3 + 7*x**2 + 18*x + 128
# 1232

# %% [markdown]
# ## SymPy’s polynomial simple univariate polynomial factorization
# - https://docs.sympy.org/latest/modules/polys/wester.html#simple-univariate-polynomial-factorization
# - factor(x\*\*4 - 2\*x\*\*3  - 45\*x\*\*2 - 34\*x + 80)

# %% [markdown]
# ![Wolfram3.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**4 - 2*x**3  - 45*x**2 - 34*x + 80)
# Out:
# (x - 8)*(x - 1)*(x + 2)*(x + 5)

# %% [markdown]
# ## SymPy’s solvers
# - https://docs.sympy.org/latest/tutorial/solvers.html
#  x\*\*4 - 2\*x\*\*3  - 45\*x\*\* 2 - 34\*x + 80 = 0

# %% [markdown]
# ![Wolfram 4.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq
x = Symbol('x')
solveset(Eq(x**4 - 2*x**3  - 45*x**2 - 34*x + 80, 0), x)
# Out:
# FiniteSet(-5, -2, 1, 8)

# %% [markdown]
# ![Wolfram5.png](data:image/png;base64,...)

# %%
from sympy import Symbol, solveset, Eq, sqrt, pi
x = Symbol('x')
solveset(Eq(x**2 - (sqrt(2))*x + sqrt(2) , 0), x)
# Out:
# FiniteSet(sqrt(2)/2 - sqrt(2)*I*sqrt(-1 + 2*sqrt(2))/2, sqrt(2)/2 + sqrt(2)*I*sqrt(-1 + 2*sqrt(2))/2)

# %% [markdown]
# *   Reference docs for the Poly Domains https://docs.sympy.org/dev/modules/polys/domainsref.html
#
# *   Introducing the Domains of the poly module https://docs.sympy.org/dev/modules/polys/domainsintro.html
#
# *   Internals of the Polynomial Manipulation Module https://docs.sympy.org/latest/modules/polys/internals.html

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol,factor
x = Symbol('x')
factor(x**7 - 2*x**6 - x**5 + 8*x**3 - 8*x - 3,domain='GF(2)')
# Out:
# (x**2 + x + 1)*(x**5 + x**4 + x**3 + x + 1)

# %% [markdown]
# ## SymPy’s Symbolic and Numercical Complex Evaluations
# - https://docs.sympy.org/latest/modules/evalf.html](https://)
# - x = x1 + I*x2,y = y1 + I*y2, z = z1 + I*z2, x*y*z

# %% [markdown]
# <img src="https://raw.githubusercontent.com/gjhernandezp/NM/main/SymPyLab/sympylabwolfram7.jpg" />

# %%
from sympy import symbols, I, N, pi, expand
x1, x2, y1, y2, z1, z2 = symbols("x1 x2 y1 y2 z1 z2", real=True)  
x = x1 + I*x2
y = y1 + I*y2
z = z1 + I*z2

print(x*y*z)
print(expand(x*y*z))
print(expand((x*y)*z))
print(expand(x*(y*z)))

w=N(1/(pi + I), 20)
print('w=',w)
# Out:
# (x1 + I*x2)*(y1 + I*y2)*(z1 + I*z2)
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# x1*y1*z1 + I*x1*y1*z2 + I*x1*y2*z1 - x1*y2*z2 + I*x2*y1*z1 - x2*y1*z2 - x2*y2*z1 - I*x2*y2*z2
# w= 0.28902548222223624241 - 0.091999668350375232456*I

# %% [markdown]
# ## Wolfram alpha answers quastion in natural languaje
# - What is the average salary in Colombia?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## SymPy’s integrate

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(1/x, x)
# Out:
# log(x)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from sympy import Symbol, integrate, sin
x = Symbol('x')
integrate(sin(x)**3, (x,pi,2*pi))
# Out:
# -4/3

# %%
from sympy import Symbol, integrate, sin, N
x = Symbol('x')
N(integrate(x**3 * sin(x), (x,1,5)))
# Out:
# -93.2907811456801
