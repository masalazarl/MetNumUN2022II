# %% [markdown]
# <a href="https://colab.research.google.com/github/masalazarl/MetNumUN2022II/blob/main/LAB%203/masalazarl_lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![masalazarlcognitiveclassaapplieddatadciencewithpython - 2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![masalazarlcognitiveclassaapplieddatadciencewithpython - 1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![masalazarlcognitiveclassaapplieddatadciencewithpython - 3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # Linkedin:
# www.linkedin.com/in/maria-alejandra-salazar-lasso-a97087252

# %% [markdown]
# ![imagen_2022-09-27_060417981.png](data:image/png;base64,...)
